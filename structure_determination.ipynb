# %%
import pandas as pd
import random
import numpy as np
from matplotlib import pyplot as plt

import torch
import dgl
import networkx as nx

import sys
sys.path.append('/home/benhonore/molecular_generator/molecular_generator/')

import make_molecules as mm
from random_generator import draw_graph_connectivity
from predict_and_rank import rank_structures
# Out:
# Using backend: pytorch

# %% [markdown]
# **EXAMPLES**

# %% [markdown]
# _**Propan-1-ol**_

# %%
df=pd.read_pickle('small_molecules_testing/2D/2d_propan_1_ol_atoms.pkl')
graph, mask = mm.make_full_graph(df)
real_graph = mm.make_real_graph(df)
draw_graph_connectivity(graph)
# Out:
# /home/benhonore/miniconda3/envs/gtn/lib/python3.8/site-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)

# %%
mols, lmf, count = mm.find_molecules(df, 4)
h_e, c_e = rank_structures(mols)
# Out:
# molecules found: 3
# 1000 iterations since last molecule found: 3 molecules found.
# Final Structure..

# %% [markdown]
# Compare the edges/connectivity to confirm that it has got this right.

# %%
h_output = h_e[0][1]
list(h_output.edata['distance']) == list(real_graph.edata['distance'])
# Out:
# True

# %%
c_output = c_e[0][1]
list(c_output.edata['distance']) == list(real_graph.edata['distance'])
# Out:
# True

# %% [markdown]
# The errors on carbon and proton both rank the correct structure top.

# %% [markdown]
# **But-2-en-1-ol**

# %%
df = pd.read_pickle('small_molecules_testing/2D/2d_but_2_en_1_ol_atoms.pkl')
graph, mask = mm.make_full_graph(df)
real_graph = mm.make_real_graph(df)
draw_graph_connectivity(graph)
# Out:
# /home/benhonore/miniconda3/envs/gtn/lib/python3.8/site-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)

# %%
mols, lmf, count = mm.find_molecules(df, 1000)
h_e, c_e = rank_structures(mols)
# Out:
# molecules found: 8
# 1000 iterations since last molecule found: 8 molecules found.
# Final Structure..

# %% [markdown]
# The errors on carbon and proton both rank the correct structure top.

# %% [markdown]
# **But-3-en-2-ol**

# %%
df = pd.read_pickle('small_molecules_testing/2D/2d_but_3_en_2_ol_atoms.pkl')
graph, mask = mm.make_full_graph(df)
real_graph = mm.make_real_graph(df)
draw_graph_connectivity(graph)
# Out:
# /home/benhonore/miniconda3/envs/gtn/lib/python3.8/site-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)

# %%
mols, lmf, count = mm.find_molecules(df, 1000)
h_e, c_e = rank_structures(mols)
# Out:
# molecules found: 9
# 1000 iterations since last molecule found: 9 molecules found.
# Final Structure..

# %% [markdown]
# The errors on carbon and proton both rank the correct structure top.

# %% [markdown]
# **Pentan-1-ol**

# %%
df=pd.read_pickle('small_molecules_testing/2D/2d_pentan_1_ol_atoms.pkl')
graph, mask = mm.make_full_graph(df)
real_graph = mm.make_real_graph(df)
draw_graph_connectivity(graph)
# Out:
# /home/benhonore/miniconda3/envs/gtn/lib/python3.8/site-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)

# %%
mols, lmf, count = mm.find_molecules(df, 1000)
h_e, c_e = rank_structures(mols)
# Out:
# molecules found: 45
# 1000 iterations since last molecule found: 45 molecules found.
# Final Structure..

# %% [markdown]
# The errors on carbon and proton both rank the correct structure top.
